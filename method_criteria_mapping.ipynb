# %%
import numpy as np
import pandas as pd


#import expert judgement from the spreadsheet in form of numpy arrays
file_loc = r'C:\Users\moallemie\GitHub\Method selection paper\Supplementary Information 2.xlsx'
criteria_stage = pd.read_excel(io=file_loc, sheet_name='Criteria-Stages', usecols="D:N",skiprows=4, index_col=0)
criteria_context = pd.read_excel(io=file_loc, sheet_name='Criteria-Context', usecols="D:F",skiprows=4, index_col=0)
method_criteria = pd.read_excel(io=file_loc, sheet_name='Methods-Criteria', usecols="C:AD",skiprows=4, index_col=0)

# %%
criteria_stage
# Out:
#                                                     Visioning  Target Setting  \
# Agenda setting                                           1.00            1.00
# Exploring scenarios                                      1.00            0.50
# Analysing solutions                                      0.25            0.25
# Understanding the system                                 0.25            0.25
# Vulnerability analysis                                   0.25            0.25
# Working with quantitative indicators                     0.25            0.25
# Working with qualitative indicators                      1.00            1.00
# Capturing system details                                 0.25            0.50
# Easy communication of results                            1.00            1.00
# Dealing with high problem complexity                     0.25            0.25
# Dealing with high problem uncertainty                    0.25            0.25
# Working under limited data availability                  0.25            0.25
# Building on existing participatory experience            1.00            1.00
# Building on existing computational experience            0.25            0.25
# Working under limited hardware and software access       0.25            0.25
# Engaging with cross-sectoral actors                      1.00            1.00
# Engaging with single sector practitioners                0.50            0.50
# Engaging with policymakers                               1.00            1.00
# Enabling front-end participation                         1.00            1.00
# Enabling back-end participation                          1.00            0.25
# Extracting information from stakeholders                 0.25            0.25
# Creating co-learning between stakeholders                0.25            0.25
# Co-design/managing with stakeholders                     1.00            1.00
# Working under stakeholder fatigue                        1.00            0.25
# Working under limited strategic thinking maturity        0.25            1.00
# Coping with divergence of values                         1.00            1.00
# Co-creating buy-in and ownership of results              1.00            1.00
#
#                                                     Scenario Framing  \
# Agenda setting                                                  0.50
# Exploring scenarios                                             1.00
# Analysing solutions                                             0.25
# Understanding the system                                        0.50
# Vulnerability analysis                                          1.00
# Working with quantitative indicators                            0.50
# Working with qualitative indicators                             0.50
# Capturing system details                                        1.00
# Easy communication of results                                   0.25
# Dealing with high problem complexity                            0.25
# Dealing with high problem uncertainty                           1.00
# Working under limited data availability                         1.00
# Building on existing participatory experience                   0.50
# Building on existing computational experience                   1.00
# Working under limited hardware and software access              1.00
# Engaging with cross-sectoral actors                             0.25
# Engaging with single sector practitioners                       1.00
# Engaging with policymakers                                      1.00
# Enabling front-end participation                                1.00
# Enabling back-end participation                                 0.25
# Extracting information from stakeholders                        0.25
# Creating co-learning between stakeholders                       1.00
# Co-design/managing with stakeholders                            0.25
# Working under stakeholder fatigue                               0.50
# Working under limited strategic thinking maturity               0.50
# Coping with divergence of values                                1.00
# Co-creating buy-in and ownership of results                     0.25
#
#                                                     Problem Analysis  \
# Agenda setting                                                  0.25
# Exploring scenarios                                             0.25
# Analysing solutions                                             1.00
# Understanding the system                                        1.00
# Vulnerability analysis                                          1.00
# Working with quantitative indicators                            0.25
# Working with qualitative indicators                             1.00
# Capturing system details                                        0.50
# Easy communication of results                                   0.25
# Dealing with high problem complexity                            1.00
# Dealing with high problem uncertainty                           0.25
# Working under limited data availability                         0.50
# Building on existing participatory experience                   1.00
# Building on existing computational experience                   0.25
# Working under limited hardware and software access              0.25
# Engaging with cross-sectoral actors                             1.00
# Engaging with single sector practitioners                       1.00
# Engaging with policymakers                                      0.25
# Enabling front-end participation                                1.00
# Enabling back-end participation                                 0.25
# Extracting information from stakeholders                        0.25
# Creating co-learning between stakeholders                       1.00
# Co-design/managing with stakeholders                            0.25
# Working under stakeholder fatigue                               1.00
# Working under limited strategic thinking maturity               1.00
# Coping with divergence of values                                1.00
# Co-creating buy-in and ownership of results                     0.25
#
#                                                     Actions Formulation  \
# Agenda setting                                                     0.25
# Exploring scenarios                                                0.25
# Analysing solutions                                                1.00
# Understanding the system                                           0.50
# Vulnerability analysis                                             0.25
# Working with quantitative indicators                               0.25
# Working with qualitative indicators                                1.00
# Capturing system details                                           1.00
# Easy communication of results                                      0.25
# Dealing with high problem complexity                               0.25
# Dealing with high problem uncertainty                              0.25
# Working under limited data availability                            1.00
# Building on existing participatory experience                      1.00
# Building on existing computational experience                      1.00
# Working under limited hardware and software access                 1.00
# Engaging with cross-sectoral actors                                0.50
# Engaging with single sector practitioners                          1.00
# Engaging with policymakers                                         0.50
# Enabling front-end participation                                   1.00
# Enabling back-end participation                                    0.25
# Extracting information from stakeholders                           0.25
# Creating co-learning between stakeholders                          0.25
# Co-design/managing with stakeholders                               1.00
# Working under stakeholder fatigue                                  1.00
# Working under limited strategic thinking maturity                  1.00
# Coping with divergence of values                                   1.00
# Co-creating buy-in and ownership of results                        0.25
#
#                                                     Actions Evaluation  \
# Agenda setting                                                    0.25
# Exploring scenarios                                               0.50
# Analysing solutions                                               0.50
# Understanding the system                                          1.00
# Vulnerability analysis                                            1.00
# Working with quantitative indicators                              1.00
# Working with qualitative indicators                               0.25
# Capturing system details                                          0.50
# Easy communication of results                                     0.25
# Dealing with high problem complexity                              1.00
# Dealing with high problem uncertainty                             1.00
# Working under limited data availability                           0.50
# Building on existing participatory experience                     0.25
# Building on existing computational experience                     1.00
# Working under limited hardware and software access                1.00
# Engaging with cross-sectoral actors                               0.25
# Engaging with single sector practitioners                         0.50
# Engaging with policymakers                                        0.25
# Enabling front-end participation                                  0.25
# Enabling back-end participation                                   1.00
# Extracting information from stakeholders                          1.00
# Creating co-learning between stakeholders                         0.25
# Co-design/managing with stakeholders                              0.25
# Working under stakeholder fatigue                                 0.50
# Working under limited strategic thinking maturity                 1.00
# Coping with divergence of values                                  0.25
# Co-creating buy-in and ownership of results                       0.25
#
#                                                     Pathways Assembly  \
# Agenda setting                                                   0.25
# Exploring scenarios                                              0.25
# Analysing solutions                                              1.00
# Understanding the system                                         0.50
# Vulnerability analysis                                           0.25
# Working with quantitative indicators                             0.25
# Working with qualitative indicators                              1.00
# Capturing system details                                         1.00
# Easy communication of results                                    0.25
# Dealing with high problem complexity                             0.25
# Dealing with high problem uncertainty                            0.25
# Working under limited data availability                          1.00
# Building on existing participatory experience                    1.00
# Building on existing computational experience                    1.00
# Working under limited hardware and software access               1.00
# Engaging with cross-sectoral actors                              0.25
# Engaging with single sector practitioners                        0.50
# Engaging with policymakers                                       0.50
# Enabling front-end participation                                 0.25
# Enabling back-end participation                                  1.00
# Extracting information from stakeholders                         1.00
# Creating co-learning between stakeholders                        0.25
# Co-design/managing with stakeholders                             0.25
# Working under stakeholder fatigue                                1.00
# Working under limited strategic thinking maturity                1.00
# Coping with divergence of values                                 1.00
# Co-creating buy-in and ownership of results                      0.25
#
#                                                     Pathways Selection  \
# Agenda setting                                                    0.25
# Exploring scenarios                                               0.50
# Analysing solutions                                               0.50
# Understanding the system                                          1.00
# Vulnerability analysis                                            0.25
# Working with quantitative indicators                              1.00
# Working with qualitative indicators                               1.00
# Capturing system details                                          0.50
# Easy communication of results                                     1.00
# Dealing with high problem complexity                              1.00
# Dealing with high problem uncertainty                             1.00
# Working under limited data availability                           0.50
# Building on existing participatory experience                     0.50
# Building on existing computational experience                     1.00
# Working under limited hardware and software access                1.00
# Engaging with cross-sectoral actors                               0.25
# Engaging with single sector practitioners                         0.50
# Engaging with policymakers                                        1.00
# Enabling front-end participation                                  0.25
# Enabling back-end participation                                   1.00
# Extracting information from stakeholders                          0.25
# Creating co-learning between stakeholders                         0.25
# Co-design/managing with stakeholders                              1.00
# Working under stakeholder fatigue                                 1.00
# Working under limited strategic thinking maturity                 1.00
# Coping with divergence of values                                  1.00
# Co-creating buy-in and ownership of results                       1.00
#
#                                                     Monitoring System  \
# Agenda setting                                                   0.25
# Exploring scenarios                                              0.25
# Analysing solutions                                              0.25
# Understanding the system                                         0.25
# Vulnerability analysis                                           1.00
# Working with quantitative indicators                             0.50
# Working with qualitative indicators                              0.25
# Capturing system details                                         0.50
# Easy communication of results                                    1.00
# Dealing with high problem complexity                             0.50
# Dealing with high problem uncertainty                            0.50
# Working under limited data availability                          1.00
# Building on existing participatory experience                    0.50
# Building on existing computational experience                    0.50
# Working under limited hardware and software access               0.50
# Engaging with cross-sectoral actors                              0.50
# Engaging with single sector practitioners                        1.00
# Engaging with policymakers                                       1.00
# Enabling front-end participation                                 0.25
# Enabling back-end participation                                  1.00
# Extracting information from stakeholders                         0.25
# Creating co-learning between stakeholders                        0.25
# Co-design/managing with stakeholders                             1.00
# Working under stakeholder fatigue                                0.50
# Working under limited strategic thinking maturity                0.50
# Coping with divergence of values                                 0.50
# Co-creating buy-in and ownership of results                      0.50
#
#                                                     Contingency Planning
# Agenda setting                                                      0.25
# Exploring scenarios                                                 0.25
# Analysing solutions                                                 0.25
# Understanding the system                                            0.25
# Vulnerability analysis                                              1.00
# Working with quantitative indicators                                0.50
# Working with qualitative indicators                                 0.50
# Capturing system details                                            0.50
# Easy communication of results                                       1.00
# Dealing with high problem complexity                                1.00
# Dealing with high problem uncertainty                               1.00
# Working under limited data availability                             1.00
# Building on existing participatory experience                       1.00
# Building on existing computational experience                       1.00
# Working under limited hardware and software access                  1.00
# Engaging with cross-sectoral actors                                 0.25
# Engaging with single sector practitioners                           1.00
# Engaging with policymakers                                          1.00
# Enabling front-end participation                                    1.00
# Enabling back-end participation                                     1.00
# Extracting information from stakeholders                            0.25
# Creating co-learning between stakeholders                           1.00
# Co-design/managing with stakeholders                                0.25
# Working under stakeholder fatigue                                   1.00
# Working under limited strategic thinking maturity                   1.00
# Coping with divergence of values                                    0.50
# Co-creating buy-in and ownership of results                         0.50

# %%
criteria_context
# Out:
#                                                     Goulburn Murray case  \
# Agenda setting                                                         2
# Exploring scenarios                                                    3
# Analysing solutions                                                    2
# Understanding the system                                               3
# Vulnerability analysis                                                 3
# Working with quantitative indicators                                   3
# Working with qualitative indicators                                    2
# Capturing system details                                               3
# Easy communication of results                                          3
# Dealing with high problem complexity                                   3
# Dealing with high problem uncertainty                                  3
# Working under limited data availability                                1
# Building on existing participatory experience                          3
# Building on existing computational experience                          3
# Working under limited hardware and software access                     3
# Engaging with cross-sectoral actors                                    2
# Engaging with single sector practitioners                              3
# Engaging with policymakers                                             3
# Enabling front-end participation                                       1
# Enabling back-end participation                                        2
# Extracting information from stakeholders                               1
# Creating co-learning between stakeholders                              2
# Co-design/managing with stakeholders                                   3
# Working under stakeholder fatigue                                      3
# Working under limited strategic thinking maturity                      3
# Coping with divergence of values                                       1
# Co-creating buy-in and ownership of results                            3
#
#                                                     Forrest/Otways case
# Agenda setting                                                        3
# Exploring scenarios                                                   3
# Analysing solutions                                                   3
# Understanding the system                                              3
# Vulnerability analysis                                                3
# Working with quantitative indicators                                  1
# Working with qualitative indicators                                   3
# Capturing system details                                              1
# Easy communication of results                                         3
# Dealing with high problem complexity                                  1
# Dealing with high problem uncertainty                                 1
# Working under limited data availability                               3
# Building on existing participatory experience                         3
# Building on existing computational experience                         1
# Working under limited hardware and software access                    1
# Engaging with cross-sectoral actors                                   3
# Engaging with single sector practitioners                             1
# Engaging with policymakers                                            2
# Enabling front-end participation                                      3
# Enabling back-end participation                                       3
# Extracting information from stakeholders                              3
# Creating co-learning between stakeholders                             3
# Co-design/managing with stakeholders                                  3
# Working under stakeholder fatigue                                     1
# Working under limited strategic thinking maturity                     1
# Coping with divergence of values                                      2
# Co-creating buy-in and ownership of results                           2

# %%
method_criteria
# Out:
#                                   Agenda (vision, targets) setting  \
# Surveys                                                          3
# Interviews                                                       3
# Open space                                                       3
# Facilitation                                                     3
# Brainstorming                                                    2
# Role-playing games                                               1
# Rich pictures                                                    3
# Visual representation                                            3
# SWOT analysis                                                    1
# Sociotechnical imaginaries                                       3
# Q methodology                                                    3
# Fuzzy cognitive mapping                                          2
# Cultural consensus                                               3
# Causal loop diagram                                              1
# Deliberative mapping                                             3
# Cognitive mapping                                                2
# Content analysis                                                 3
# Narrative analysis                                               3
# Literature review                                                3
# Observation                                                      2
# Cross-impact-balance analysis                                    3
# Crossover points analysis                                        1
# Participatory GIS                                                3
# Crowdsourcing                                                    3
# Multi-criteria decision analysis                                 1
# Decision tree analysis                                           1
# System dynamics modelling                                        1
# Agent-based modelling                                            1
# Transitions modelling                                            1
# Integrated assessment modelling                                  1
# Story-and-simulation                                             1
# Cost-benefit analysis                                            1
# Network analysis                                                 1
# Input-output analysis                                            1
# Life cycle assessment                                            1
# Bayesian networks analysis                                       1
# Time series analysis                                             1
# Statistical analysis                                             1
# Econometric analysis                                             1
# Biophysical modelling                                            1
# Scenario discovery                                               1
# Sensitivity analysis                                             1
# Robust optimisation                                              1
#
#                                   Exploring scenarios  Analysing solutions  \
# Surveys                                             2                    2
# Interviews                                          3                    3
# Open space                                          3                    3
# Facilitation                                        3                    3
# Brainstorming                                       3                    3
# Role-playing games                                  1                    3
# Rich pictures                                       2                    1
# Visual representation                               3                    1
# SWOT analysis                                       2                    3
# Sociotechnical imaginaries                          3                    1
# Q methodology                                       3                    2
# Fuzzy cognitive mapping                             1                    1
# Cultural consensus                                  1                    2
# Causal loop diagram                                 1                    2
# Deliberative mapping                                1                    3
# Cognitive mapping                                   1                    1
# Content analysis                                    3                    2
# Narrative analysis                                  3                    3
# Literature review                                   3                    3
# Observation                                         1                    1
# Cross-impact-balance analysis                       3                    1
# Crossover points analysis                           3                    1
# Participatory GIS                                   1                    1
# Crowdsourcing                                       3                    3
# Multi-criteria decision analysis                    1                    3
# Decision tree analysis                              1                    3
# System dynamics modelling                           2                    1
# Agent-based modelling                               2                    1
# Transitions modelling                               2                    1
# Integrated assessment modelling                     2                    1
# Story-and-simulation                                3                    3
# Cost-benefit analysis                               1                    1
# Network analysis                                    1                    1
# Input-output analysis                               1                    1
# Life cycle assessment                               1                    1
# Bayesian networks analysis                          3                    1
# Time series analysis                                3                    1
# Statistical analysis                                1                    1
# Econometric analysis                                1                    1
# Biophysical modelling                               2                    1
# Scenario discovery                                  3                    1
# Sensitivity analysis                                3                    3
# Robust optimisation                                 3                    3
#
#                                   Understanding the system  \
# Surveys                                                  1
# Interviews                                               3
# Open space                                               2
# Facilitation                                             2
# Brainstorming                                            1
# Role-playing games                                       3
# Rich pictures                                            1
# Visual representation                                    1
# SWOT analysis                                            1
# Sociotechnical imaginaries                               1
# Q methodology                                            1
# Fuzzy cognitive mapping                                  3
# Cultural consensus                                       1
# Causal loop diagram                                      3
# Deliberative mapping                                     1
# Cognitive mapping                                        3
# Content analysis                                         1
# Narrative analysis                                       3
# Literature review                                        1
# Observation                                              3
# Cross-impact-balance analysis                            2
# Crossover points analysis                                1
# Participatory GIS                                        2
# Crowdsourcing                                            1
# Multi-criteria decision analysis                         1
# Decision tree analysis                                   1
# System dynamics modelling                                3
# Agent-based modelling                                    3
# Transitions modelling                                    3
# Integrated assessment modelling                          3
# Story-and-simulation                                     3
# Cost-benefit analysis                                    2
# Network analysis                                         3
# Input-output analysis                                    3
# Life cycle assessment                                    3
# Bayesian networks analysis                               3
# Time series analysis                                     3
# Statistical analysis                                     3
# Econometric analysis                                     3
# Biophysical modelling                                    3
# Scenario discovery                                       1
# Sensitivity analysis                                     2
# Robust optimisation                                      1
#
#                                   Vulnerability analysis  \
# Surveys                                                1
# Interviews                                             3
# Open space                                             3
# Facilitation                                           3
# Brainstorming                                          3
# Role-playing games                                     1
# Rich pictures                                          1
# Visual representation                                  1
# SWOT analysis                                          3
# Sociotechnical imaginaries                             1
# Q methodology                                          1
# Fuzzy cognitive mapping                                1
# Cultural consensus                                     1
# Causal loop diagram                                    1
# Deliberative mapping                                   1
# Cognitive mapping                                      1
# Content analysis                                       1
# Narrative analysis                                     1
# Literature review                                      1
# Observation                                            2
# Cross-impact-balance analysis                          1
# Crossover points analysis                              3
# Participatory GIS                                      1
# Crowdsourcing                                          3
# Multi-criteria decision analysis                       1
# Decision tree analysis                                 3
# System dynamics modelling                              1
# Agent-based modelling                                  1
# Transitions modelling                                  1
# Integrated assessment modelling                        1
# Story-and-simulation                                   1
# Cost-benefit analysis                                  1
# Network analysis                                       3
# Input-output analysis                                  1
# Life cycle assessment                                  1
# Bayesian networks analysis                             1
# Time series analysis                                   1
# Statistical analysis                                   1
# Econometric analysis                                   1
# Biophysical modelling                                  1
# Scenario discovery                                     3
# Sensitivity analysis                                   3
# Robust optimisation                                    3
#
#                                   Working with quantitative indicators  \
# Surveys                                                              3
# Interviews                                                           1
# Open space                                                           1
# Facilitation                                                         1
# Brainstorming                                                        1
# Role-playing games                                                   1
# Rich pictures                                                        1
# Visual representation                                                1
# SWOT analysis                                                        1
# Sociotechnical imaginaries                                           1
# Q methodology                                                        1
# Fuzzy cognitive mapping                                              2
# Cultural consensus                                                   1
# Causal loop diagram                                                  1
# Deliberative mapping                                                 1
# Cognitive mapping                                                    1
# Content analysis                                                     2
# Narrative analysis                                                   1
# Literature review                                                    2
# Observation                                                          1
# Cross-impact-balance analysis                                        2
# Crossover points analysis                                            2
# Participatory GIS                                                    3
# Crowdsourcing                                                        3
# Multi-criteria decision analysis                                     2
# Decision tree analysis                                               1
# System dynamics modelling                                            3
# Agent-based modelling                                                3
# Transitions modelling                                                3
# Integrated assessment modelling                                      3
# Story-and-simulation                                                 3
# Cost-benefit analysis                                                3
# Network analysis                                                     3
# Input-output analysis                                                3
# Life cycle assessment                                                3
# Bayesian networks analysis                                           3
# Time series analysis                                                 3
# Statistical analysis                                                 3
# Econometric analysis                                                 3
# Biophysical modelling                                                3
# Scenario discovery                                                   3
# Sensitivity analysis                                                 3
# Robust optimisation                                                  3
#
#                                   Working with qualitative indicators  \
# Surveys                                                             3
# Interviews                                                          3
# Open space                                                          3
# Facilitation                                                        3
# Brainstorming                                                       3
# Role-playing games                                                  3
# Rich pictures                                                       3
# Visual representation                                               3
# SWOT analysis                                                       3
# Sociotechnical imaginaries                                          3
# Q methodology                                                       3
# Fuzzy cognitive mapping                                             3
# Cultural consensus                                                  3
# Causal loop diagram                                                 3
# Deliberative mapping                                                3
# Cognitive mapping                                                   3
# Content analysis                                                    3
# Narrative analysis                                                  3
# Literature review                                                   3
# Observation                                                         3
# Cross-impact-balance analysis                                       3
# Crossover points analysis                                           3
# Participatory GIS                                                   3
# Crowdsourcing                                                       3
# Multi-criteria decision analysis                                    3
# Decision tree analysis                                              3
# System dynamics modelling                                           1
# Agent-based modelling                                               1
# Transitions modelling                                               1
# Integrated assessment modelling                                     1
# Story-and-simulation                                                3
# Cost-benefit analysis                                               1
# Network analysis                                                    1
# Input-output analysis                                               1
# Life cycle assessment                                               1
# Bayesian networks analysis                                          1
# Time series analysis                                                1
# Statistical analysis                                                1
# Econometric analysis                                                1
# Biophysical modelling                                               1
# Scenario discovery                                                  1
# Sensitivity analysis                                                1
# Robust optimisation                                                 1
#
#                                   Capturing system details  \
# Surveys                                                  3
# Interviews                                               3
# Open space                                               2
# Facilitation                                             2
# Brainstorming                                            2
# Role-playing games                                       2
# Rich pictures                                            2
# Visual representation                                    2
# SWOT analysis                                            2
# Sociotechnical imaginaries                               2
# Q methodology                                            3
# Fuzzy cognitive mapping                                  1
# Cultural consensus                                       3
# Causal loop diagram                                      2
# Deliberative mapping                                     3
# Cognitive mapping                                        2
# Content analysis                                         3
# Narrative analysis                                       3
# Literature review                                        3
# Observation                                              3
# Cross-impact-balance analysis                            1
# Crossover points analysis                                1
# Participatory GIS                                        3
# Crowdsourcing                                            3
# Multi-criteria decision analysis                         1
# Decision tree analysis                                   1
# System dynamics modelling                                1
# Agent-based modelling                                    3
# Transitions modelling                                    3
# Integrated assessment modelling                          1
# Story-and-simulation                                     2
# Cost-benefit analysis                                    1
# Network analysis                                         3
# Input-output analysis                                    1
# Life cycle assessment                                    2
# Bayesian networks analysis                               3
# Time series analysis                                     1
# Statistical analysis                                     1
# Econometric analysis                                     1
# Biophysical modelling                                    2
# Scenario discovery                                       3
# Sensitivity analysis                                     3
# Robust optimisation                                      3
#
#                                   Easy communication of results  \
# Surveys                                                       3
# Interviews                                                    3
# Open space                                                    3
# Facilitation                                                  3
# Brainstorming                                                 3
# Role-playing games                                            3
# Rich pictures                                                 3
# Visual representation                                         3
# SWOT analysis                                                 3
# Sociotechnical imaginaries                                    3
# Q methodology                                                 3
# Fuzzy cognitive mapping                                       2
# Cultural consensus                                            3
# Causal loop diagram                                           2
# Deliberative mapping                                          3
# Cognitive mapping                                             2
# Content analysis                                              3
# Narrative analysis                                            3
# Literature review                                             3
# Observation                                                   3
# Cross-impact-balance analysis                                 2
# Crossover points analysis                                     2
# Participatory GIS                                             3
# Crowdsourcing                                                 3
# Multi-criteria decision analysis                              2
# Decision tree analysis                                        2
# System dynamics modelling                                     1
# Agent-based modelling                                         1
# Transitions modelling                                         1
# Integrated assessment modelling                               1
# Story-and-simulation                                          2
# Cost-benefit analysis                                         2
# Network analysis                                              1
# Input-output analysis                                         2
# Life cycle assessment                                         2
# Bayesian networks analysis                                    1
# Time series analysis                                          2
# Statistical analysis                                          2
# Econometric analysis                                          2
# Biophysical modelling                                         1
# Scenario discovery                                            1
# Sensitivity analysis                                          1
# Robust optimisation                                           1
#
#                                   Dealing with high problem complexity  ...  \
# Surveys                                                              1  ...
# Interviews                                                           1  ...
# Open space                                                           1  ...
# Facilitation                                                         1  ...
# Brainstorming                                                        1  ...
# Role-playing games                                                   2  ...
# Rich pictures                                                        1  ...
# Visual representation                                                1  ...
# SWOT analysis                                                        1  ...
# Sociotechnical imaginaries                                           1  ...
# Q methodology                                                        1  ...
# Fuzzy cognitive mapping                                              2  ...
# Cultural consensus                                                   1  ...
# Causal loop diagram                                                  2  ...
# Deliberative mapping                                                 2  ...
# Cognitive mapping                                                    2  ...
# Content analysis                                                     1  ...
# Narrative analysis                                                   1  ...
# Literature review                                                    1  ...
# Observation                                                          1  ...
# Cross-impact-balance analysis                                        2  ...
# Crossover points analysis                                            1  ...
# Participatory GIS                                                    1  ...
# Crowdsourcing                                                        1  ...
# Multi-criteria decision analysis                                     1  ...
# Decision tree analysis                                               2  ...
# System dynamics modelling                                            3  ...
# Agent-based modelling                                                3  ...
# Transitions modelling                                                3  ...
# Integrated assessment modelling                                      3  ...
# Story-and-simulation                                                 3  ...
# Cost-benefit analysis                                                1  ...
# Network analysis                                                     3  ...
# Input-output analysis                                                3  ...
# Life cycle assessment                                                3  ...
# Bayesian networks analysis                                           3  ...
# Time series analysis                                                 2  ...
# Statistical analysis                                                 2  ...
# Econometric analysis                                                 2  ...
# Biophysical modelling                                                3  ...
# Scenario discovery                                                   3  ...
# Sensitivity analysis                                                 3  ...
# Robust optimisation                                                  3  ...
#
#                                   Engaging with policymakers  \
# Surveys                                                    2
# Interviews                                                 3
# Open space                                                 2
# Facilitation                                               3
# Brainstorming                                              3
# Role-playing games                                         3
# Rich pictures                                              3
# Visual representation                                      3
# SWOT analysis                                              3
# Sociotechnical imaginaries                                 3
# Q methodology                                              3
# Fuzzy cognitive mapping                                    3
# Cultural consensus                                         3
# Causal loop diagram                                        3
# Deliberative mapping                                       3
# Cognitive mapping                                          3
# Content analysis                                           1
# Narrative analysis                                         1
# Literature review                                          1
# Observation                                                3
# Cross-impact-balance analysis                              3
# Crossover points analysis                                  3
# Participatory GIS                                          1
# Crowdsourcing                                              1
# Multi-criteria decision analysis                           3
# Decision tree analysis                                     3
# System dynamics modelling                                  2
# Agent-based modelling                                      2
# Transitions modelling                                      2
# Integrated assessment modelling                            1
# Story-and-simulation                                       1
# Cost-benefit analysis                                      3
# Network analysis                                           1
# Input-output analysis                                      1
# Life cycle assessment                                      1
# Bayesian networks analysis                                 2
# Time series analysis                                       1
# Statistical analysis                                       1
# Econometric analysis                                       1
# Biophysical modelling                                      1
# Scenario discovery                                         2
# Sensitivity analysis                                       2
# Robust optimisation                                        2
#
#                                   Enabling front-end participation  \
# Surveys                                                          3
# Interviews                                                       3
# Open space                                                       3
# Facilitation                                                     3
# Brainstorming                                                    3
# Role-playing games                                               3
# Rich pictures                                                    3
# Visual representation                                            3
# SWOT analysis                                                    2
# Sociotechnical imaginaries                                       3
# Q methodology                                                    3
# Fuzzy cognitive mapping                                          3
# Cultural consensus                                               3
# Causal loop diagram                                              3
# Deliberative mapping                                             3
# Cognitive mapping                                                3
# Content analysis                                                 1
# Narrative analysis                                               1
# Literature review                                                1
# Observation                                                      3
# Cross-impact-balance analysis                                    3
# Crossover points analysis                                        3
# Participatory GIS                                                3
# Crowdsourcing                                                    3
# Multi-criteria decision analysis                                 3
# Decision tree analysis                                           3
# System dynamics modelling                                        2
# Agent-based modelling                                            2
# Transitions modelling                                            2
# Integrated assessment modelling                                  2
# Story-and-simulation                                             1
# Cost-benefit analysis                                            2
# Network analysis                                                 1
# Input-output analysis                                            1
# Life cycle assessment                                            1
# Bayesian networks analysis                                       2
# Time series analysis                                             1
# Statistical analysis                                             1
# Econometric analysis                                             1
# Biophysical modelling                                            1
# Scenario discovery                                               1
# Sensitivity analysis                                             2
# Robust optimisation                                              1
#
#                                   Enabling back-end participation  \
# Surveys                                                         1
# Interviews                                                      1
# Open space                                                      3
# Facilitation                                                    3
# Brainstorming                                                   1
# Role-playing games                                              2
# Rich pictures                                                   2
# Visual representation                                           1
# SWOT analysis                                                   3
# Sociotechnical imaginaries                                      2
# Q methodology                                                   2
# Fuzzy cognitive mapping                                         1
# Cultural consensus                                              2
# Causal loop diagram                                             2
# Deliberative mapping                                            2
# Cognitive mapping                                               2
# Content analysis                                                1
# Narrative analysis                                              1
# Literature review                                               1
# Observation                                                     1
# Cross-impact-balance analysis                                   2
# Crossover points analysis                                       1
# Participatory GIS                                               1
# Crowdsourcing                                                   1
# Multi-criteria decision analysis                                1
# Decision tree analysis                                          2
# System dynamics modelling                                       1
# Agent-based modelling                                           1
# Transitions modelling                                           1
# Integrated assessment modelling                                 1
# Story-and-simulation                                            2
# Cost-benefit analysis                                           1
# Network analysis                                                1
# Input-output analysis                                           2
# Life cycle assessment                                           2
# Bayesian networks analysis                                      1
# Time series analysis                                            2
# Statistical analysis                                            2
# Econometric analysis                                            2
# Biophysical modelling                                           1
# Scenario discovery                                              2
# Sensitivity analysis                                            2
# Robust optimisation                                             2
#
#                                   Extracting information from stakeholders  \
# Surveys                                                                  3
# Interviews                                                               3
# Open space                                                               1
# Facilitation                                                             1
# Brainstorming                                                            1
# Role-playing games                                                       1
# Rich pictures                                                            1
# Visual representation                                                    1
# SWOT analysis                                                            1
# Sociotechnical imaginaries                                               1
# Q methodology                                                            3
# Fuzzy cognitive mapping                                                  3
# Cultural consensus                                                       1
# Causal loop diagram                                                      1
# Deliberative mapping                                                     2
# Cognitive mapping                                                        1
# Content analysis                                                         1
# Narrative analysis                                                       3
# Literature review                                                        1
# Observation                                                              1
# Cross-impact-balance analysis                                            1
# Crossover points analysis                                                1
# Participatory GIS                                                        3
# Crowdsourcing                                                            3
# Multi-criteria decision analysis                                         1
# Decision tree analysis                                                   1
# System dynamics modelling                                                1
# Agent-based modelling                                                    1
# Transitions modelling                                                    1
# Integrated assessment modelling                                          1
# Story-and-simulation                                                     1
# Cost-benefit analysis                                                    1
# Network analysis                                                         1
# Input-output analysis                                                    1
# Life cycle assessment                                                    1
# Bayesian networks analysis                                               1
# Time series analysis                                                     2
# Statistical analysis                                                     2
# Econometric analysis                                                     2
# Biophysical modelling                                                    1
# Scenario discovery                                                       1
# Sensitivity analysis                                                     1
# Robust optimisation                                                      1
#
#                                   Creating co-learning between stakeholders  \
# Surveys                                                                   1
# Interviews                                                                1
# Open space                                                                3
# Facilitation                                                              3
# Brainstorming                                                             3
# Role-playing games                                                        3
# Rich pictures                                                             3
# Visual representation                                                     2
# SWOT analysis                                                             1
# Sociotechnical imaginaries                                                3
# Q methodology                                                             2
# Fuzzy cognitive mapping                                                   1
# Cultural consensus                                                        3
# Causal loop diagram                                                       3
# Deliberative mapping                                                      3
# Cognitive mapping                                                         3
# Content analysis                                                          1
# Narrative analysis                                                        1
# Literature review                                                         1
# Observation                                                               2
# Cross-impact-balance analysis                                             1
# Crossover points analysis                                                 1
# Participatory GIS                                                         1
# Crowdsourcing                                                             1
# Multi-criteria decision analysis                                          1
# Decision tree analysis                                                    2
# System dynamics modelling                                                 1
# Agent-based modelling                                                     1
# Transitions modelling                                                     1
# Integrated assessment modelling                                           1
# Story-and-simulation                                                      2
# Cost-benefit analysis                                                     1
# Network analysis                                                          1
# Input-output analysis                                                     1
# Life cycle assessment                                                     1
# Bayesian networks analysis                                                2
# Time series analysis                                                      1
# Statistical analysis                                                      1
# Econometric analysis                                                      1
# Biophysical modelling                                                     1
# Scenario discovery                                                        2
# Sensitivity analysis                                                      2
# Robust optimisation                                                       2
#
#                                   Co-designing/managing with stakeholders  \
# Surveys                                                                 1
# Interviews                                                              1
# Open space                                                              3
# Facilitation                                                            3
# Brainstorming                                                           3
# Role-playing games                                                      3
# Rich pictures                                                           3
# Visual representation                                                   3
# SWOT analysis                                                           3
# Sociotechnical imaginaries                                              3
# Q methodology                                                           1
# Fuzzy cognitive mapping                                                 1
# Cultural consensus                                                      3
# Causal loop diagram                                                     3
# Deliberative mapping                                                    2
# Cognitive mapping                                                       3
# Content analysis                                                        1
# Narrative analysis                                                      1
# Literature review                                                       1
# Observation                                                             1
# Cross-impact-balance analysis                                           2
# Crossover points analysis                                               2
# Participatory GIS                                                       2
# Crowdsourcing                                                           1
# Multi-criteria decision analysis                                        2
# Decision tree analysis                                                  3
# System dynamics modelling                                               2
# Agent-based modelling                                                   2
# Transitions modelling                                                   2
# Integrated assessment modelling                                         2
# Story-and-simulation                                                    2
# Cost-benefit analysis                                                   2
# Network analysis                                                        1
# Input-output analysis                                                   2
# Life cycle assessment                                                   2
# Bayesian networks analysis                                              1
# Time series analysis                                                    1
# Statistical analysis                                                    1
# Econometric analysis                                                    1
# Biophysical modelling                                                   1
# Scenario discovery                                                      1
# Sensitivity analysis                                                    1
# Robust optimisation                                                     1
#
#                                   Working under stakeholder fatigue  \
# Surveys                                                           1
# Interviews                                                        1
# Open space                                                        1
# Facilitation                                                      1
# Brainstorming                                                     1
# Role-playing games                                                1
# Rich pictures                                                     1
# Visual representation                                             1
# SWOT analysis                                                     1
# Sociotechnical imaginaries                                        1
# Q methodology                                                     1
# Fuzzy cognitive mapping                                           2
# Cultural consensus                                                1
# Causal loop diagram                                               2
# Deliberative mapping                                              1
# Cognitive mapping                                                 1
# Content analysis                                                  3
# Narrative analysis                                                3
# Literature review                                                 3
# Observation                                                       2
# Cross-impact-balance analysis                                     1
# Crossover points analysis                                         3
# Participatory GIS                                                 1
# Crowdsourcing                                                     1
# Multi-criteria decision analysis                                  2
# Decision tree analysis                                            2
# System dynamics modelling                                         2
# Agent-based modelling                                             3
# Transitions modelling                                             2
# Integrated assessment modelling                                   3
# Story-and-simulation                                              3
# Cost-benefit analysis                                             3
# Network analysis                                                  3
# Input-output analysis                                             3
# Life cycle assessment                                             3
# Bayesian networks analysis                                        2
# Time series analysis                                              3
# Statistical analysis                                              3
# Econometric analysis                                              3
# Biophysical modelling                                             3
# Scenario discovery                                                3
# Sensitivity analysis                                              3
# Robust optimisation                                               3
#
#                                   Working under limited strategic thinking maturity   \
# Surveys                                                                           2
# Interviews                                                                        1
# Open space                                                                        2
# Facilitation                                                                      1
# Brainstorming                                                                     2
# Role-playing games                                                                1
# Rich pictures                                                                     3
# Visual representation                                                             3
# SWOT analysis                                                                     1
# Sociotechnical imaginaries                                                        2
# Q methodology                                                                     3
# Fuzzy cognitive mapping                                                           1
# Cultural consensus                                                                3
# Causal loop diagram                                                               1
# Deliberative mapping                                                              1
# Cognitive mapping                                                                 1
# Content analysis                                                                  3
# Narrative analysis                                                                3
# Literature review                                                                 3
# Observation                                                                       3
# Cross-impact-balance analysis                                                     1
# Crossover points analysis                                                         1
# Participatory GIS                                                                 3
# Crowdsourcing                                                                     3
# Multi-criteria decision analysis                                                  1
# Decision tree analysis                                                            1
# System dynamics modelling                                                         2
# Agent-based modelling                                                             2
# Transitions modelling                                                             2
# Integrated assessment modelling                                                   2
# Story-and-simulation                                                              2
# Cost-benefit analysis                                                             2
# Network analysis                                                                  3
# Input-output analysis                                                             2
# Life cycle assessment                                                             2
# Bayesian networks analysis                                                        3
# Time series analysis                                                              3
# Statistical analysis                                                              3
# Econometric analysis                                                              3
# Biophysical modelling                                                             3
# Scenario discovery                                                                2
# Sensitivity analysis                                                              2
# Robust optimisation                                                               2
#
#                                   Coping with divergence of values   \
# Surveys                                                           3
# Interviews                                                        2
# Open space                                                        3
# Facilitation                                                      3
# Brainstorming                                                     3
# Role-playing games                                                2
# Rich pictures                                                     3
# Visual representation                                             3
# SWOT analysis                                                     2
# Sociotechnical imaginaries                                        3
# Q methodology                                                     3
# Fuzzy cognitive mapping                                           2
# Cultural consensus                                                3
# Causal loop diagram                                               1
# Deliberative mapping                                              3
# Cognitive mapping                                                 1
# Content analysis                                                  3
# Narrative analysis                                                2
# Literature review                                                 2
# Observation                                                       2
# Cross-impact-balance analysis                                     1
# Crossover points analysis                                         1
# Participatory GIS                                                 3
# Crowdsourcing                                                     3
# Multi-criteria decision analysis                                  1
# Decision tree analysis                                            1
# System dynamics modelling                                         1
# Agent-based modelling                                             3
# Transitions modelling                                             1
# Integrated assessment modelling                                   1
# Story-and-simulation                                              1
# Cost-benefit analysis                                             1
# Network analysis                                                  1
# Input-output analysis                                             1
# Life cycle assessment                                             1
# Bayesian networks analysis                                        1
# Time series analysis                                              1
# Statistical analysis                                              1
# Econometric analysis                                              1
# Biophysical modelling                                             1
# Scenario discovery                                                3
# Sensitivity analysis                                              3
# Robust optimisation                                               3
#
#                                   Co-creating buy-in and ownership of results
# Surveys                                                                     3
# Interviews                                                                  3
# Open space                                                                  3
# Facilitation                                                                3
# Brainstorming                                                               3
# Role-playing games                                                          3
# Rich pictures                                                               3
# Visual representation                                                       3
# SWOT analysis                                                               2
# Sociotechnical imaginaries                                                  3
# Q methodology                                                               3
# Fuzzy cognitive mapping                                                     2
# Cultural consensus                                                          3
# Causal loop diagram                                                         2
# Deliberative mapping                                                        3
# Cognitive mapping                                                           2
# Content analysis                                                            1
# Narrative analysis                                                          1
# Literature review                                                           1
# Observation                                                                 2
# Cross-impact-balance analysis                                               2
# Crossover points analysis                                                   2
# Participatory GIS                                                           2
# Crowdsourcing                                                               3
# Multi-criteria decision analysis                                            2
# Decision tree analysis                                                      2
# System dynamics modelling                                                   1
# Agent-based modelling                                                       1
# Transitions modelling                                                       1
# Integrated assessment modelling                                             1
# Story-and-simulation                                                        1
# Cost-benefit analysis                                                       1
# Network analysis                                                            1
# Input-output analysis                                                       1
# Life cycle assessment                                                       1
# Bayesian networks analysis                                                  1
# Time series analysis                                                        1
# Statistical analysis                                                        1
# Econometric analysis                                                        1
# Biophysical modelling                                                       1
# Scenario discovery                                                          1
# Sensitivity analysis                                                        1
# Robust optimisation                                                         1
#
# [43 rows x 27 columns]

# %%
method_criteria_t = method_criteria.transpose()

# %%
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns


criteria = criteria_stage.index.tolist()
methods = method_criteria.index.tolist()


fig, ax = plt.subplots(1, 1, figsize=(12, 8.5))
sns.set(font_scale=1.2)


sns.heatmap(method_criteria_t, center=2.5, vmin=1, vmax=3, fmt = '', cmap='OrRd', 
                cbar_kws = dict({'ticks': [1, 2, 3]}, use_gridspec=False,location="bottom", aspect=10, shrink=.2, pad=.1, anchor=(-.3, -.4)), 
                linewidths=1, xticklabels=True, yticklabels=True, ax=ax)


ax.tick_params(axis='x', rotation=90)

    
#ax.xaxis.tick_top()
ax.tick_params(left=False, bottom=False, top=False)

ax.collections[0].colorbar.set_label("Method suitability")
ax.collections[0].colorbar.set_ticklabels(['Limited', 'Moderate', 'High'])


plt.subplots_adjust(wspace=.2, hspace=.09)

plt.savefig('{}/fig{}.pdf'.format(r'C:\Users\moallemie\GitHub\Method selection paper\Figs', '_method-criteria'), 
            dpi=600, bbox_inches='tight')

# %%
criteria = criteria_stage.index.tolist()
contexts = criteria_context.columns.values.tolist()
methods = method_criteria.index.tolist()
stages = criteria_stage.columns.values.tolist()

#create an empty dict to save stage-method arrays per each SDG
dict_stage_method = {}

#Calculate stage-method array and save it in dict
for i,context in enumerate(contexts): 
    dict_stage_method[context] = np.empty([len(stages), len(methods)])
    for j in range(len(stages)):        #iterate between stages     
        for k in range(len(methods)):     #iterate between methods
            sum_stage_method = 0
            for m in range(len(criteria)):  #iterate between criteria
                sum_stage_method += 1-abs((criteria_context.iloc[m,i]-method_criteria.iloc[k,m])/2)*criteria_stage.iloc[m,j]
            dict_stage_method[context][j,k] = sum_stage_method/len(criteria)

# %%
#create a shared cbar for heatmap
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns

fig, axes = plt.subplots(1, 2, sharex=False, sharey=True, figsize=(7, 13))
sns.set(font_scale=1.2)


#create colourmap for heatmaps based on context colour
context_colour = {'Goulburn Murray case':'YlGnBu', 'Forrest/Otways case':'YlGnBu'}


#Draw heatmaps
for i, (context, ax) in enumerate(zip(contexts, axes.flat)):
    pd_stage_method = pd.DataFrame.from_records(dict_stage_method[context], columns=methods, index=stages)
    pd_stage_method_t = pd_stage_method.transpose()
    
    labels = pd.DataFrame(index=methods, columns=stages)
    labels = labels.replace(np.nan, '', regex=True)

    for i, stage in enumerate(stages):
        top5 = list(pd_stage_method_t.nlargest(5, stage).index)
        for j, method in enumerate(top5):
            labels.loc[method, stage] = str(j+1)
            

    sns.heatmap(pd_stage_method_t, center=.8, vmin=.6, vmax=1, annot=labels, 
                annot_kws={'size':11, 'weight':'semibold',  "ha": 'center',"va": 'center', 'color':'black'}, fmt = '', cmap='YlGnBu', 
                cbar_kws = dict(use_gridspec=False,location="bottom", pad=0.15, anchor=(0, -.25)), 
                linewidths=4, xticklabels=True, yticklabels=True, ax=ax)
        
    ax.tick_params(axis='x', rotation=90)

    
    ax.xaxis.tick_top()
    ax.tick_params(left=False, bottom=False, top=False)
    
plt.subplots_adjust(wspace=.2, hspace=.09)


plt.savefig('{}/fig{}.pdf'.format(r'C:\Users\moallemie\GitHub\Method selection paper\Figs', '_heatplot'), 
            dpi=600, bbox_inches='tight')
